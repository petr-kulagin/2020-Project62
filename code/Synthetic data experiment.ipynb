# %%
import numpy as np
import dtaidistance.dtw
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-ada5176fab44> in <module>
#       1 import numpy as np
# ----> 2 import dtaidistance.dtw
#       3 import matplotlib.pyplot as plt
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'dtaidistance'

# %%
conda install dtaidistance
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - dtaidistance
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Искусственные данные для сравнения 2 алгоритмов

# %% [markdown]
# Для генерации искусственных данных будем использовать шаблон из 2 сигналов

# %%
signal1 = np.array([0, 1, 0])
signal2 = np.array([1, 0, 1])


plt.plot(np.arange(3), signal1)
plt.title('1 тип сигнала')
plt.xlabel('Номер измерения')
plt.ylabel('Значение измерения')
plt.show()

# %%
plt.plot(np.arange(3), signal2)
plt.title('2 тип сигнала')
plt.xlabel('Номер измерения')
plt.ylabel('Значение измерения')
plt.show()

# %% [markdown]
# Для построения примера 2 временных рядов будем использовать их в качестве шаблона.

# %% [markdown]
# Для начала посмотрим на расстояние между ними, используя L2-метрику и DTW.

# %%
def L2_metric(sign1, sign2):
    return np.sum((sign1 - sign2) ** 2) ** 0.5

dtaidistance.dtw.distance_fast(s1, s2
